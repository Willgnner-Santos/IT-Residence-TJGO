# %%
# Importa o módulo 'csv' da biblioteca padrão do Python, usado para manipular arquivos CSV.
import csv

# Define o caminho completo do arquivo CSV a ser lido.
caminho_arquivo = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.csv'

# Abre o arquivo em modo leitura ('r'), com codificação UTF-8
with open(caminho_arquivo, 'r', encoding='utf-8') as arquivo:
    # Cria um objeto Sniffer, que detecta automaticamente o formato (dialeto) do CSV
    sniffer = csv.Sniffer()

    # Lê uma amostra inicial do arquivo (2048 caracteres) para que o Sniffer possa analisar
    amostra = arquivo.read(2048)

    # Retorna o ponteiro para o início do arquivo, pois a leitura anterior avançou o cursor
    arquivo.seek(0)

    # Detecta automaticamente o delimitador (como vírgula, ponto e vírgula, etc.) e o caractere de aspas
    dialeto = sniffer.sniff(amostra)

    # Exibe informações sobre o dialeto detectado
    print(f"Delimitador detectado: {repr(dialeto.delimiter)}")
    print(f"Caractere de aspas detectado: {repr(dialeto.quotechar)}")
    print(f"Primeiras 5 linhas para inspeção:")

    # Cria um leitor CSV usando o dialeto detectado
    leitor = csv.reader(arquivo, delimiter=dialeto.delimiter, quotechar=dialeto.quotechar)

    # Itera pelas primeiras 5 linhas do arquivo e imprime cada uma
    for i, linha in enumerate(leitor):
        print(linha)
        if i >= 4:
            break  # Interrompe o loop após imprimir 5 linhas
# Out:
# Delimitador detectado: '\t'
# Caractere de aspas detectado: '"'
# Primeiras 5 linhas para inspeção:
# ['numero_processo', 'comarca', 'serventia', 'assunto', 'classe', 'polo_ativo', 'polo_passivo', 'cpf_cnpj_polo_ativo', 'cpf_cnpj_polo_passivo', 'inteiro_teor', 'codg_cnj_audi', 'codg_cnj_julgamento', 'classificacao']
# ['5437249.35.2024.8.09.0075', 'IPAMERI', 'Ipameri - Juizado Especial Cível', 'DIREITO CIVIL -> Obrigações -> Espécies de Títulos de Crédito -> Nota Promissória', 'PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimento do Juizado Especial Cível', 'Dds Tecidos E Confeccoes Ltda', 'Vania Alves Fidelis', '7590793000195', '91795591153', '>>>>>inicio<<<<<\nEscritório de Advocacia Silva Endereço: Avenida Costa e Silva, n° 0, Lado Boa Vista – 2, Bairro Alto da Boa Vista, Ipameri/GO, CEP: 75780-000. Telefone: (64) 9.9918-1634 e-mail: edienialves@hotmail.com P á  g in  a 1   EXCELENTÍSSIMO (A) SENHOR (A) DOUTOR (A) JUIZ (A) DE DIREITO DO JUIZADO ESPECIAL CIVEL DA COMARCA DE IPAMERI – ESTADO DE GOIÁS. Natureza: Ação de Cobrança; Requerente: DDS Tecidos e Confecções LTDA; Requerida: Vânia Fidelis; Advogada: Edieni Alves da Silva Vaz – OAB/GO 42.482; Medida: Petição Inicial. DDS TECIDOS E CONFECÇÕES LTDA, pessoa jurídica de direito privado, com nome fantasia UNIÃO TECIDOS, com CNPJ de nº 07.590.793/0001-95, com endereço na Rua General Mascarenhas de Morais, Centro, Ipameri/GO, CEP: 75780-000, neste ato por sua representante legal Aparecida Firmino De Melo, brasileira, casada, empresária, portadora do CPF de nº 546.154.881-49 e inscrita no Registro Geral de nº 3467895 2ª Via, expedida pela SSP/GO,
QUINQUENAL. NÃO VERIFICADA. CORREÇÃO MONETÁRIA E JUROS DE MORA. TERMO INICIAL. VENCIMENTO DA OBRIGAÇÃO. CORREÇÃO PELO IGP-M/FGV. NÃO ABUSIVIDADE. CAPITALIZAÇÃO MENSAL INCOMPROVADA. PREQUESTIONAMENTO. HONORÁRIOS. MAJORAÇÃO. SENTENÇA MANTIDA. 1. É quinquenal o prazo prescricional para ajuizamento da ação monitória fundada em nota promissória (título sem força executiva)  ...

# %%
import csv

# Aumenta o limite de caracteres permitidos por campo no CSV para 10 milhões.
# Isso evita erros quando campos (como "inteiro_teor") têm textos muito longos.
csv.field_size_limit(10_000_000)

# Define o caminho do arquivo CSV que será lido
caminho_arquivo = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.csv'

# Abre o arquivo em modo leitura, com codificação UTF-8
with open(caminho_arquivo, 'r', encoding='utf-8') as arquivo:
    
    # Cria um leitor CSV, assumindo que os campos são separados por tabulação (\t)
    # e que os campos podem estar entre aspas duplas
    leitor = csv.reader(arquivo, delimiter='\t', quotechar='"')
    
    # Lê a primeira linha do arquivo como cabeçalho
    cabecalho = next(leitor)
    
    # Conta quantas colunas existem no cabeçalho (quantidade esperada por linha)
    num_colunas = len(cabecalho)

    # Inicializa uma lista para armazenar as linhas que têm problemas
    linhas_problematicas = []

    # Percorre cada linha do CSV, a partir da segunda (por isso start=2)
    for i, linha in enumerate(leitor, start=2):
        # Verifica se o número de colunas da linha atual bate com o do cabeçalho
        if len(linha) != num_colunas:
            # Se não bater, adiciona à lista de linhas problemáticas
            linhas_problematicas.append((i, linha))

# Exibe quantas linhas foram identificadas com erro de coluna
print(f"{len(linhas_problematicas)} linhas com número incorreto de colunas.")

# Exibe as primeiras 5 linhas problemáticas para inspeção
for linha in linhas_problematicas[:5]:
    print(f"Linha {linha[0]}: {linha[1]}")
# Out:
# 40725 linhas com número incorreto de colunas.
# Linha 2: ['5000309.96.2025.8.09.0174', 'SENADOR CANEDO', 'Senador Canedo - Juizado Especial Cível', 'DIREITO DO CONSUMIDOR -> Responsabilidade do Fornecedor -> Indenização por Dano Material', 'PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimento do Juizado Especial Cível', 'William Da Silva Raimundo', 'Apdap Prev-associacao De Protecao E Defesa Dos Direitos Dos Aposentados E Pensionistas', '72970057115', '7699920000199', '>>>>>inicio<<<<<\nAO JUÍZO DA VARA DO SISTEMA DOS JUIZADOS DA COMARCA DE SENADOR CANEDO-GO WILLIAN DA SILVA RAIMUNDO, brasileiro, casado, aposentado, inscrito no CPF sob nº 729.700.571-15, portador da cédula de identidade RG sob nº 4860220, residente e domiciliado na Avenida Raimundo Pinto, SN – Vila Bom Sucesso, Senador Canedo - GO, 75261, vem respeitosamente, por seu advogado, à presença de Vossa Excelência, propor a presente AÇÃO DE CANCELAMENTO DE SERVIÇO NÃO CONTRATADO C/C DANOS MORAIS, MATERIAIS (COM REPETIÇÃO DE INDÉBITO) E PEDIDO DE ANTECIPAÇÃO DE TUTELA. Em face da APD
'	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 923: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 925: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 926: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 928: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 932: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 940: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 941: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 985: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 988: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 990: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 992: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 994: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 998: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1015: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1019: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1021: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1023: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1025: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1032: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1034: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1035: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1037: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1038: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1040: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1041: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1043: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1046: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1048: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1051: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1053: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1054: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1077: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1078: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1080: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1081: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1095: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1096: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1098: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1099: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1122: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1123: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1125: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1127: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1132: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1133: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1135: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1136: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1147: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1149: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1151: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1152: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1154: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1155: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1157: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1159: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1161: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1162: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1164: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1166: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1177: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1178: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1189: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1190: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1201: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 1202: '	' expected after '"'
#
#   df = pd.read_csv(
# ...
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45406: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45408: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45413: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45430: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45431: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45451: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45452: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45454: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45456: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45467: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45470: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45472: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45473: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45475: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45476: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45478: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45479: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45496: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45497: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45499: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45500: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45502: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45507: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45509: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45513: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45515: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45516: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45518: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45519: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45533: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45534: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45536: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45539: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45541: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45546: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45548: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45550: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45552: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45553: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45555: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45557: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45568: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45572: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45577: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45581: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45592: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45593: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45595: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45604: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45606: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45608: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45616: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45618: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45638: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45643: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45645: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45646: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45648: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45652: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45654: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45655: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45657: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45658: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45660: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45661: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45663: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45664: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45666: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45667: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45669: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45672: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45674: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45676: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45678: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45679: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45687: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45690: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45692: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45694: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45708: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45711: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45713: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45714: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45716: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45718: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45720: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45721: '	' expected after '"'
#
#   df = pd.read_csv(
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\149887677.py:7: ParserWarning: Skipping line 45723: '	' expected after '"'
#
#   df = pd.read_csv(
# Index(['numero_processo', 'comarca', 'serventia', 'assunto', 'classe',
#        'polo_ativo', 'polo_passivo', 'cpf_cnpj_polo_ativo',
#        'cpf_cnpj_polo_passivo', 'inteiro_teor', 'codg_cnj_audi',
#        'codg_cnj_julgamento', 'classificacao'],
#       dtype='object')
# (35832, 13)
#                                                0  \
# numero_processo        #####fim#####id:405715990
# comarca                                     None
# serventia                                   None
# assunto                                     None
# classe                                      None
# polo_ativo                                  None
# polo_passivo                                None
# cpf_cnpj_polo_ativo                         None
# cpf_cnpj_polo_passivo                       None
# inteiro_teor                                None
# codg_cnj_audi                                NaN
# codg_cnj_julgamento                          NaN
# classificacao                               None
#
#                                                                        1
# numero_processo                                5000399.26.2025.8.09.0103
# comarca                                                           MINAÇU
# serventia                            Minaçu - Vara das Fazendas Públicas
# assunto                DIREITO PREVIDENCIÁRIO -> Benefícios em Espéci...
# classe                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Co...
# polo_ativo                             Regina De Fatima Dos Santos Alves
# polo_passivo                         Instituto Nacional Do Seguro Social
# cpf_cnpj_polo_ativo                                          98093720197
# cpf_cnpj_polo_passivo                                     29979036000140
# inteiro_teor           >>>>>inicio<<<<<\nRua 04, centro, Campinaçu-Go...
# codg_cnj_audi                                                        NaN
# codg_cnj_julgamento                                                466.0
# classificacao                                                  frutifero

# %%
# Caminhos para o arquivo de entrada (original) e o arquivo de saída (limpo)
input_path = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.csv'
output_path = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V1.csv'

linhas_validas = []  # Lista onde serão armazenadas apenas as linhas válidas

# Abre o arquivo CSV original para leitura
with open(input_path, 'r', encoding='utf-8') as f_in:
    leitor = csv.reader(f_in, delimiter='\t', quotechar='"')  # Usa tabulação como separador e aspas como delimitador de campo
    for row in leitor:
        # Ignora linhas que contenham um marcador de fim customizado
        if len(row) == 1 and row[0].startswith('#####fim#####id:'):
            continue
        # Adiciona à lista apenas linhas que têm exatamente 13 colunas (esperado no esquema)
        if len(row) == 13:
            linhas_validas.append(row)

# Abre (ou cria) um novo arquivo para salvar as linhas limpas
with open(output_path, 'w', encoding='utf-8', newline='') as f_out:
    escritor = csv.writer(f_out, delimiter='\t', quotechar='"', quoting=csv.QUOTE_ALL)  # Define o formato de escrita
    # Escreve o cabeçalho no novo arquivo (nomes das 13 colunas esperadas)
    escritor.writerow([
        'numero_processo', 'comarca', 'serventia', 'assunto', 'classe',
        'polo_ativo', 'polo_passivo', 'cpf_cnpj_polo_ativo', 'cpf_cnpj_polo_passivo',
        'inteiro_teor', 'codg_cnj_audi', 'codg_cnj_julgamento', 'classificacao'
    ])
    # Escreve todas as linhas válidas coletadas anteriormente
    escritor.writerows(linhas_validas)

# Exibe quantas linhas válidas foram salvas no novo arquivo
print(f"{len(linhas_validas)} registros válidos salvos.")
# Out:
# 4997 registros válidos salvos.

# %%
try:
    # Tenta ler o CSV limpo (salvo anteriormente) usando o pandas
    df = pd.read_csv(
        output_path,        # Caminho para o arquivo já limpo
        sep='\t',           # Delimitador de campos: tabulação
        quotechar='"',      # Caractere que envolve textos com separadores
        encoding='utf-8',   # Codificação do arquivo
        engine='python'     # Usa o engine "python" para lidar melhor com campos complexos
    )
except Exception as e:
    # Captura e exibe qualquer erro ocorrido na leitura do arquivo
    print(f"Erro ao carregar CSV: {e}")

# Exibe o número de linhas e colunas do DataFrame carregado
print(df.shape)

# Mostra as duas primeiras linhas transpostas (útil para inspeção vertical das colunas)
print(df.head(2).transpose())
# Out:
# (4997, 13)
#                                            0  \
# numero_processo              numero_processo
# comarca                              comarca
# serventia                          serventia
# assunto                              assunto
# classe                                classe
# polo_ativo                        polo_ativo
# polo_passivo                    polo_passivo
# cpf_cnpj_polo_ativo      cpf_cnpj_polo_ativo
# cpf_cnpj_polo_passivo  cpf_cnpj_polo_passivo
# inteiro_teor                    inteiro_teor
# codg_cnj_audi                  codg_cnj_audi
# codg_cnj_julgamento      codg_cnj_julgamento
# classificacao                  classificacao
#
#                                                                        1
# numero_processo                                5000399.26.2025.8.09.0103
# comarca                                                           MINAÇU
# serventia                            Minaçu - Vara das Fazendas Públicas
# assunto                DIREITO PREVIDENCIÁRIO -> Benefícios em Espéci...
# classe                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Co...
# polo_ativo                             Regina De Fatima Dos Santos Alves
# polo_passivo                         Instituto Nacional Do Seguro Social
# cpf_cnpj_polo_ativo                                          98093720197
# cpf_cnpj_polo_passivo                                     29979036000140
# inteiro_teor           >>>>>inicio<<<<<\nRua 04, centro, Campinaçu-Go...
# codg_cnj_audi                                                        NaN
# codg_cnj_julgamento                                                  466
# classificacao                                                  frutifero

# %%
# Conta quantas vezes cada valor aparece na coluna 'classificacao'
# Útil para ver o balanço entre classes como 'frutifero' e 'infrutifero'
df['classificacao'].value_counts()

# Calcula a proporção de valores ausentes (NaN) em cada coluna
# Mostra em ordem decrescente de colunas mais incompletas para menos
df.isna().mean().sort_values(ascending=False)

# Mede o comprimento (número de caracteres) de cada valor na coluna 'inteiro_teor'
# Em seguida, gera estatísticas descritivas (média, mínimo, máximo, quartis etc.)
df['inteiro_teor'].str.len().describe()
# Out:
# count      4997.000000
# mean      14294.346008
# std       23438.525962
# min          12.000000
# 25%        5634.000000
# 50%        9685.000000
# 75%       17205.000000
# max      813597.000000
# Name: inteiro_teor, dtype: float64

# %%
import pandas as pd

# Função para gerar um resumo estatístico e informativo de um DataFrame
def resumo_dataset(df):
    resumo = pd.DataFrame({
        # Tipo de dado de cada coluna (object, int64, float64, etc.)
        'Tipo de Dado': df.dtypes,
        
        # Total de linhas (será o mesmo para todas as colunas)
        'Total de Valores': len(df),
        
        # Quantidade de valores não nulos por coluna
        'Não Nulos': df.notnull().sum(),
        
        # Quantidade de valores nulos por coluna
        'Nulos': df.isnull().sum(),
        
        # Porcentagem de valores nulos por coluna
        '% de Nulos': df.isnull().mean() * 100,
        
        # Número de valores únicos por coluna
        'Valores Únicos': df.nunique(),
        
        # Um exemplo aleatório de valor não nulo da coluna (útil para inspecionar)
        'Exemplo': df.apply(lambda x: x.dropna().sample(1).values[0] if x.dropna().size > 0 else None)
    })

    # Reorganiza as colunas para melhor leitura
    resumo = resumo[['Tipo de Dado', 'Total de Valores', 'Não Nulos', 'Nulos', '% de Nulos', 'Valores Únicos', 'Exemplo']]
    
    # Ordena pelas colunas com maior percentual de nulos no topo
    return resumo.sort_values(by='% de Nulos', ascending=False)

# Aplica a função ao DataFrame carregado
resumo_df = resumo_dataset(df)

# Exibe o resultado de forma legível no notebook
from IPython.display import display
display(resumo_df)
# Out:
#                       Tipo de Dado  Total de Valores  Não Nulos  Nulos  \
# codg_cnj_julgamento         object              4997       2618   2379
# codg_cnj_audi               object              4997       3828   1169
# polo_passivo                object              4997       4951     46
# cpf_cnpj_polo_passivo       object              4997       4951     46
# numero_processo             object              4997       4997      0
# classe                      object              4997       4997      0
# assunto                     object              4997       4997      0
# serventia                   object              4997       4997      0
# comarca                     object              4997       4997      0
# cpf_cnpj_polo_ativo         object              4997       4997      0
# polo_ativo                  object              4997       4997      0
# inteiro_teor                object              4997       4997      0
# classificacao               object              4997       4997      0
#
#                        % de Nulos  Valores Únicos  \
# codg_cnj_julgamento     47.608565               5
# codg_cnj_audi           23.394036              10
# polo_passivo             0.920552            3711
# cpf_cnpj_polo_passivo    0.920552            3536
# numero_processo          0.000000            4997
# classe                   0.000000              77
# assunto                  0.000000             493
# serventia                0.000000             430
# comarca                  0.000000             117
# cpf_cnpj_polo_ativo      0.000000            3724
# polo_ativo               0.000000            3740
# inteiro_teor             0.000000            4997
# classificacao            0.000000               3
#
#                                                                  Exemplo
# codg_cnj_julgamento                                                  466
# codg_cnj_audi                                                      12624
# polo_passivo                         Instituto Nacional Do Seguro Social
# cpf_cnpj_polo_passivo                                     59285411000113
# numero_processo                                5103957.92.2025.8.09.0077
# classe                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Co...
# assunto                DIREITO CIVIL -> Obrigações -> Espécies de Tít...
# serventia              Goiânia - 1ª UPJ Varas Cíveis: 1ª, 2ª, 3ª, 4ª ...
# comarca                                                          GOIÂNIA
# cpf_cnpj_polo_ativo                                          71497431107
# polo_ativo                                          MUNICIPIO DE GOIANIA
# inteiro_teor           >>>>>inicio<<<<<\nEXCELENTÍSSIMO SENHOR DOUTOR...
# classificacao                                                infrutifero

# %%
# Conta a frequência de cada valor presente na coluna 'classificacao'
# O parâmetro dropna=False garante que valores ausentes (NaN) também sejam contabilizados
df['classificacao'].value_counts(dropna=False)
# Out:
# classificacao
# frutifero        2617
# infrutifero      2379
# classificacao       1
# Name: count, dtype: int64

# %%
df[df['classificacao'] == 'classificacao']
# Out:
#    numero_processo  comarca  serventia  assunto  classe  polo_ativo  \
# 0  numero_processo  comarca  serventia  assunto  classe  polo_ativo
#
#    polo_passivo  cpf_cnpj_polo_ativo  cpf_cnpj_polo_passivo  inteiro_teor  \
# 0  polo_passivo  cpf_cnpj_polo_ativo  cpf_cnpj_polo_passivo  inteiro_teor
#
#    codg_cnj_audi  codg_cnj_julgamento  classificacao
# 0  codg_cnj_audi  codg_cnj_julgamento  classificacao

# %%
# Conta quantas linhas duplicadas existem no DataFrame inteiro (todas as colunas devem ser idênticas)
print(df.duplicated().sum())

# Remove as linhas duplicadas, mantendo apenas a primeira ocorrência
df = df.drop_duplicates()
# Out:
# 0

# %%
# Converte a coluna 'codg_cnj_julgamento' para tipo numérico (float), 
# forçando valores inválidos (como strings não numéricas) a serem convertidos em NaN
df['codg_cnj_julgamento'] = pd.to_numeric(df['codg_cnj_julgamento'], errors='coerce')

# Faz o mesmo para a coluna 'codg_cnj_audi', garantindo que ambas tenham formato numérico consistente
df['codg_cnj_audi'] = pd.to_numeric(df['codg_cnj_audi'], errors='coerce')

# %%
# Remove espaços em branco no início/fim dos nomes das colunas (evita bugs por nomes mal formatados)
df.columns = df.columns.str.strip()

# Aplica o mesmo tratamento para todos os valores do DataFrame que forem strings: remove espaços extras
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\willgnnerferreira\AppData\Local\Temp\ipykernel_12212\1597845199.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Substitui quebras de linha (\n ou \r) no campo 'inteiro_teor' por um espaço simples
# Isso garante que o texto fique em uma linha contínua, facilitando análise e visualização
df['inteiro_teor'] = df['inteiro_teor'].str.replace(r'\n|\r', ' ', regex=True)

# %%
# Exporta o DataFrame limpo para um novo arquivo CSV
# - 'sep="\t"' define que o separador será tabulação (TSV)
# - 'index=False' evita salvar o índice numérico do pandas como uma coluna no CSV
# - 'encoding="utf-8"' assegura compatibilidade com acentuação e caracteres especiais
df.to_csv(r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V2.csv', sep='\t', index=False, encoding='utf-8')

# %%
def validar_e_corrigir_linha(linha, colunas_esperadas):
    """
    Valida e corrige uma linha de CSV.
    Retorna a linha se for válida, ou None se for inválida.

    Parâmetros:
    - linha: list[str] - linha bruta lida do arquivo
    - colunas_esperadas: int | list[str] - número esperado de colunas (ou lista de nomes de coluna)

    Regras de validação aplicadas:
    """

    # 1. Elimina linhas que são marcadores de fim de lote/exportação,
    #    normalmente usadas por sistemas para indicar encerramento de bloco
    if len(linha) == 1 and linha[0].startswith('#####fim#####id:'):
        return None

    # 2. Elimina linhas que repetem o cabeçalho original (pode ocorrer em arquivos concatenados),
    #    comparando diretamente com a lista de nomes de colunas
    if linha == colunas_esperadas:
        return None

    # 3. Descarta linhas com número incorreto de colunas (pode indicar quebra de linha mal formatada ou dado incompleto)
    if len(linha) != len(colunas_esperadas):
        return None

    # 4. Aplica strip() em cada campo textual para remover espaços em branco desnecessários
    linha = [campo.strip() if isinstance(campo, str) else campo for campo in linha]

    # Retorna a linha limpa se passou por todas as validações
    return linha

# %%
import csv

# Caminhos dos arquivos de entrada (original) e saída (limpo)
input_path = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V2.csv'
output_path = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V3.csv'

# Lista de nomes de colunas esperadas no CSV, usada tanto como cabeçalho quanto para validação
colunas = [
    'numero_processo', 'comarca', 'serventia', 'assunto', 'classe',
    'polo_ativo', 'polo_passivo', 'cpf_cnpj_polo_ativo', 'cpf_cnpj_polo_passivo',
    'inteiro_teor', 'codg_cnj_audi', 'codg_cnj_julgamento', 'classificacao'
]

# Função que valida e corrige uma linha do CSV, aplicando regras específicas
def validar_e_corrigir_linha(linha, colunas_esperadas):
    # Ignora linhas que contêm apenas um campo especial de finalização
    if len(linha) == 1 and linha[0].startswith('#####fim#####id:'):
        return None
    # Ignora linhas que repetem o cabeçalho (ocorre em arquivos concatenados)
    if linha == colunas_esperadas:
        return None
    # Ignora linhas com número incorreto de colunas
    if len(linha) != len(colunas_esperadas):
        return None
    # Aplica strip() a cada campo textual para limpeza
    return [campo.strip() if isinstance(campo, str) else campo for campo in linha]

# Lista para armazenar apenas as linhas válidas
linhas_validas = []

# Leitura do arquivo original linha a linha, aplicando validação
with open(input_path, 'r', encoding='utf-8') as f_in:
    leitor = csv.reader(f_in, delimiter='\t', quotechar='"')
    for linha in leitor:
        nova_linha = validar_e_corrigir_linha(linha, colunas)
        if nova_linha:
            linhas_validas.append(nova_linha)

# Escrita do novo arquivo com as linhas válidas e cabeçalho padronizado
with open(output_path, 'w', encoding='utf-8', newline='') as f_out:
    escritor = csv.writer(f_out, delimiter='\t', quotechar='"', quoting=csv.QUOTE_ALL)
    escritor.writerow(colunas)           # Escreve o cabeçalho
    escritor.writerows(linhas_validas)   # Escreve todas as linhas válidas

# Mensagem de confirmação com total de registros válidos salvos
print(f"{len(linhas_validas)} linhas válidas salvas em {output_path}")
# Out:
# 4997 linhas válidas salvas em C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V3.csv

# %%
# Define o caminho para o CSV já limpo (pré-processado) e o caminho de saída do JSON
csv_limpado = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V3.csv'
json_saida = r'C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.json'

# Lê o arquivo CSV usando tabulação como delimitador e aspas duplas como delimitador de texto
df = pd.read_csv(csv_limpado, sep='\t', quotechar='"', encoding='utf-8')

# Exporta para JSONL (JSON por linha) com codificação preservando acentuação (force_ascii=False)
# 'orient=records' exporta cada linha como um dicionário separado (lista de registros)
# 'lines=True' escreve cada dicionário em uma linha do arquivo => formato JSONL
df.to_json(json_saida, orient='records', force_ascii=False, lines=True)

# Confirmação visual para o usuário
print(f"Arquivo JSON exportado com sucesso para: {json_saida}")
# Out:
# Arquivo JSON exportado com sucesso para: C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.json

# %%
# Caminhos de entrada e saída
input_json_path = r"C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025.json"
output_json_path = r"C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V1.json"

# %%
import re
import pandas as pd

# Remove marcadores artificiais do texto que indicam início ou fim de registros
def limpar_marcadores(texto):
    return re.sub(r'>>>>>inicio<<<<<|#####fim#####id:\d+', '', texto)

# Remove URLs do texto (http ou https seguido por qualquer caractere não-espaço)
def remover_links(texto):
    return re.sub(r'https?://\S+', '', texto)

# Remove trechos que contenham palavras-chave relacionadas a assinaturas e autenticações
def remover_assinaturas(texto):
    return re.sub(
        r'(assinado|assinatura|OAB|Matricula|Hash SHA256|autenticação eletrônica).*',
        '', texto, flags=re.IGNORECASE
    )

# Normaliza os espaços: substitui múltiplos espaços, quebras de linha e tabs por um único espaço
def normalizar_espacos(texto):
    return re.sub(r'\s+', ' ', texto).strip()

# Anonimiza dados pessoais como CPF, RG e endereços com padrão "Rua ..."
def anonimizar_dados_pessoais(texto):
    texto = re.sub(r'\b\d{3}\.?\d{3}\.?\d{3}-?\d{2}\b', '[CPF]', texto)  # CPF
    texto = re.sub(r'\b\d{2}\.?\d{3}\.?\d{3}-?\d{1,2}\b', '[RG]', texto)   # RG
    texto = re.sub(r'Rua [^\.,;\n]+', 'Rua [REMOVIDO]', texto, flags=re.IGNORECASE)  # Endereço
    return texto

# Função principal: encadeia todas as funções de limpeza acima
def limpar_inteiro_teor(texto):
    if not isinstance(texto, str):  # Garante que só aplica em strings
        return texto
    texto = limpar_marcadores(texto)
    texto = remover_links(texto)
    texto = remover_assinaturas(texto)
    texto = anonimizar_dados_pessoais(texto)
    texto = normalizar_espacos(texto)
    return texto

# %%
# Carrega o JSONL (JSON Lines), onde cada linha representa um dicionário separado
df = pd.read_json(input_json_path, lines=True, encoding='utf-8')

# Aplica a função de limpeza 'limpar_inteiro_teor' (definida anteriormente) em cada valor da coluna 'inteiro_teor'
df['inteiro_teor'] = df['inteiro_teor'].apply(limpar_inteiro_teor)

# Exporta o DataFrame novamente para JSONL, com uma linha por registro (orient='records', lines=True)
# force_ascii=False garante que caracteres acentuados sejam mantidos corretamente no arquivo
df.to_json(output_json_path, orient='records', lines=True, force_ascii=False)

# Mensagem de confirmação
print(f"Arquivo JSON limpo salvo com sucesso em:\n{output_json_path}")
# Out:
# Arquivo JSON limpo salvo com sucesso em:
# C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V1.json

# %%
import pandas as pd

# Caminho para o arquivo CSV (mesmo que tenha extensão .json, trate como CSV!)
caminho_arquivo = r"C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V1.json"

# Tenta abrir como CSV tabulado
df = pd.read_csv(caminho_arquivo, sep='\t', quoting=3, encoding='utf-8', on_bad_lines='skip')

# Verifica colunas
print("Colunas detectadas:")
print(df.columns)

# Mostra primeiras linhas
print(df.head())
# Out:
# Colunas detectadas:
# Index(['{"numero_processo":"numero_processo","comarca":"comarca","serventia":"serventia","assunto":"assunto","classe":"classe","polo_ativo":"polo_ativo","polo_passivo":"polo_passivo","cpf_cnpj_polo_ativo":"cpf_cnpj_polo_ativo","cpf_cnpj_polo_passivo":"cpf_cnpj_polo_passivo","inteiro_teor":"inteiro_teor","codg_cnj_audi":null,"codg_cnj_julgamento":null,"classificacao":"classificacao"}'], dtype='object')
#   {"numero_processo":"numero_processo","comarca":"comarca","serventia":"serventia","assunto":"assunto","classe":"classe","polo_ativo":"polo_ativo","polo_passivo":"polo_passivo","cpf_cnpj_polo_ativo":"cpf_cnpj_polo_ativo","cpf_cnpj_polo_passivo":"cpf_cnpj_polo_passivo","inteiro_teor":"inteiro_teor","codg_cnj_audi":null,"codg_cnj_julgamento":null,"classificacao":"classificacao"}
# 0  {"numero_processo":"5000399.26.2025.8.09.0103"...
# 1  {"numero_processo":"5000507.58.2025.8.09.0005"...
# 2  {"numero_processo":"5000560.33.2025.8.09.0007"...
# 3  {"numero_processo":"5000572.20.2025.8.09.0113"...
# 4  {"numero_processo":"5000723.97.2025.8.09.0076"...

# %%
import pandas as pd

# Caminho do arquivo
caminho_arquivo = r"C:\Users\willgnnerferreira\Documents\Modelos\Perfil-Conciliação-Xgboost-GCP-V2\dados\cejusc_03072025\dados_processos_cejusc_03072025_V1.json"

# Leitura do JSON
df = pd.read_json(caminho_arquivo, lines=True)

# Exibe o número de linhas (registros) e colunas (chaves por registro)
print("Número de linhas (registros):", len(df))
print("Número de colunas:", len(df.columns))

# (Opcional) Exibe os nomes das colunas
print("\nColunas:")
print(df.columns.tolist())
# Out:
# Número de linhas (registros): 4997
# Número de colunas: 13
#
# Colunas:
# ['numero_processo', 'comarca', 'serventia', 'assunto', 'classe', 'polo_ativo', 'polo_passivo', 'cpf_cnpj_polo_ativo', 'cpf_cnpj_polo_passivo', 'inteiro_teor', 'codg_cnj_audi', 'codg_cnj_julgamento', 'classificacao']

# %%
pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\willgnnerferreira\documents\modelos\perfil-conciliação-xgboost-gcp-v2\venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
df['tokens_gpt'] = df['inteiro_teor'].astype(str).apply(lambda x: len(encoding.encode(x)))
print(df['tokens_gpt'].describe())
# Out:
# count     4997.000000
# mean      1728.011607
# std       3062.886766
# min          0.000000
# 25%        206.000000
# 50%       1139.000000
# 75%       2297.000000
# max      57504.000000
# Name: tokens_gpt, dtype: float64

# %%
df['tokens_gpt'].value_counts().sort_index()
# Out:
# tokens_gpt
# 0        81
# 1         1
# 3        21
# 4        13
# 5        37
#          ..
# 42269     1
# 43074     1
# 43181     1
# 57409     1
# 57504     1
# Name: count, Length: 2582, dtype: int64

# %%
bins = [0, 2000, 4000, 8000, 16000, float('inf')]
labels = ['até 2k', '2k–4k', '4k–8k', '8k–16k', '+16k']
df['faixa_tokens'] = pd.cut(df['tokens_gpt'], bins=bins, labels=labels)

df['faixa_tokens'].value_counts().sort_index()
# Out:
# faixa_tokens
# até 2k    3389
# 2k–4k     1047
# 4k–8k      416
# 8k–16k      42
# +16k        22
# Name: count, dtype: int64
